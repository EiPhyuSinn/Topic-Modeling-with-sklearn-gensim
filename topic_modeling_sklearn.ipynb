# %%
import pandas as pd 
data = pd.read_csv('input/data.csv',header=None)
data.head()
# Out:
#    0                                                  1  \
# 0  2                                           Great CD
# 1  2  One of the best game music soundtracks - for a...
# 2  1                   Batteries died within a year ...
# 3  2              works fine, but Maha Energy is better
# 4  2                       Great for the non-audiophile
#
#                                                    2
# 0  My lovely Pat has one of the GREAT voices of h...
# 1  Despite the fact that I have only played a sma...
# 2  I bought this charger in Jul 2003 and it worke...
# 3  Check out Maha Energy's website. Their Powerex...
# 4  Reviewed quite a bit of the combo players and ...

# %%
data.columns = ['polarity', 'title', 'text']

# %%
data = data['text']

# %%
data = data[:5000]

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
import re
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    tokens = text.split()
    tokens = [word for word in tokens if word not in ENGLISH_STOP_WORDS]
    return ' '.join(tokens)

# %%
preprocess_text = data.apply(preprocess_text)

# %%
preprocess_text[0]
# Out:
# 'lovely pat great voices generation listened cd years love im good mood makes feel better bad mood just evaporates like sugar rain cd just oozes life vocals jusat stuunning lyrics just kill lifes hidden gems desert isle cd book big just everytime play matter black white young old male female everybody says thing singing'

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(preprocess_text)

# %%
X.shape
# Out:
# (5000, 26768)

# %%
from sklearn.decomposition import LatentDirichletAllocation
lda = LatentDirichletAllocation(n_components=5, random_state=0)
lda.fit(X)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=0)

# %%
for idx, topic in enumerate(lda.components_):
    print(f"Topic {idx}:")
    print([vectorizer.get_feature_names_out()[i] for i in topic.argsort()[:-10 - 1:-1]])
# Out:
# Topic 0:
# ['book', 'read', 'books', 'reading', 'like', 'story', 'good', 'great', 'time', 'just']
# Topic 1:
# ['movie', 'book', 'good', 'like', 'great', 'just', 'film', 'really', 'read', 'time']
# Topic 2:
# ['cd', 'like', 'good', 'just', 'product', 'great', 'music', 'dont', 'songs', 'album']
# Topic 3:
# ['book', 'just', 'like', 'got', 'read', 'im', 'dont', 'good', 'really', 'great']
# Topic 4:
# ['album', 'story', 'just', 'book', 'like', 'time', 'best', 'good', 'better', 'film']
